# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import glob
import re
import itertools
import time
import joblib
import random

import pandas as pd
pd.options.display.max_columns = None
pd.options.display.max_rows = 15
pd.options.display.max_colwidth = -1
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.metrics import precision_recall_curve
from sklearn.metrics import plot_precision_recall_curve
from sklearn.metrics import average_precision_score, auc, roc_curve
from sklearn import svm, ensemble, datasets

# %%
import parsl
parsl.clear()

from polyfuse.configs.local import config
parsl.load(config)

#parsl.load()

from polyfuse import apps, transformations

# %%
out_dir = '/cephfs/users/annawoodard/polyfuse/data/sim_50/processed'
training_fraction = 0.75

# %%
truth = apps.concatenate_true_fusions('/cephfs/users/annawoodard/fusion-simulation/data/processed/*', out_dir)

# %%
truth = pd.read_hdf(truth.result(), 'data')

# %%
callers = ['starseqr', 'starfusion', 'arriba', 'fusioncatcher', 'pizzly']
indices = dict((c, i) for i, c in enumerate(callers))

# %%
parsed_caller_data = apps.parse_caller_data(out_dir, callers)

# %%
caller_data_path = apps.concatenate_caller_data(out_dir, inputs=parsed_caller_data)
caller_data = pd.read_hdf(caller_data_path.result(), 'data')

# %%
samples = sorted(caller_data['sample'].unique())
#random.shuffle(samples)
training_samples = samples[:int(len(samples) * training_fraction)]
testing_samples = samples[int(len(samples) * training_fraction):]

# %%
data = [apps.assemble_data(sample, callers, out_dir) for sample in samples]

start = time.time()
X = np.array(sum([data.result()[0] for data in data], []))
Y = np.array(sum([data.result()[1] for data in data], []))

print('assembled data in {:.1f}s'.format((time.time() - start)))
# Out:
# assembled data in 37.8s

# %%
X.shape
#import sklearn
#sorted(sklearn.metrics.SCORERS.keys())
# Out:
# (71571, 5)

# %%
start = time.time()

from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report

n = 12000
X_train, X_test, Y_train, Y_test = train_test_split(
    X[n:], Y[n:], test_size=0.5, random_state=0)


param_grid = [
    {'kernel': ['rbf'],
     'gamma': [1e-3, 1e-4],
     'C': [1, 10, 100, 1000]
    },
    {'kernel': ['linear'],
     'C': [1, 10, 100, 1000]
    }
]


param_grid = {
    'kernel': ['rbf'],
    'C': [1, 10, 100, 1000],
    'gamma': [1e-3, 1e-4, 1e-6, 1e-7, 'auto']
}

clf = GridSearchCV(
    svm.SVC(), param_grid, scoring='roc_auc', n_jobs=-1, cv=3
)
clf.fit(transformations.flatten(X_train), Y_train)

print("Best parameters set found on development set:")
print()
print(clf.best_params_)
print()
print("Grid scores on development set:")
print()
means = clf.cv_results_['mean_test_score']
stds = clf.cv_results_['std_test_score']
for mean, std, params in zip(means, stds, clf.cv_results_['params']):
    print("%0.3f (+/-%0.03f) for %r" % (mean, std * 2, params))

print('tuned parameters in {:.1f}s'.format((time.time() - start)))

# %%
training_data = [apps.assemble_data(sample, callers, out_dir) for sample in training_samples]

start = time.time()
X_train = np.array(sum([data.result()[0] for data in training_data], []))
Y_train = np.array(sum([data.result()[1] for data in training_data], []))

print('assembled data in {:.1f}s'.format((time.time() - start)))

# %%
1 / (5 * X_train.var())

# %%
start = time.time()
os.makedirs(os.path.join(out_dir, 'models'), exist_ok=True)
classifiers = []
for features in [
            #['pizzly', 'starseqr', 'fusioncatcher'],
            ['pizzly', 'starfusion', 'arriba', 'fusioncatcher'],
            callers,
            #['arriba']
            #['STARSEQR', 'PIZZLY', 'PRADA', 'FUSIONCATCHER_v1.10_June192019', 'ChimeraScan', 'ARRIBA', 'MapSplice'],
            #['STARSEQR', 'PIZZLY', 'PRADA', 'FUSIONCATCHER_v1.10_June192019', 'ChimeraScan', 'ARRIBA', 'MapSplice', 'STAR_FUSION_v1.5'],
            #['STARSEQR', 'ARRIBA', 'STAR_FUSION_v1.5']
        ]:
    
    pruned_indices = [indices[f] for f in features]
    
    label = 'LSVC{}Features'.format(len(features))
    lsvc_trans = 'flatten'
    lsvc = svm.LinearSVC()
    print(label, lsvc.get_params())
    lsvc.fit(getattr(transformations, lsvc_trans)(X_train[:, pruned_indices]), Y_train)
    joblib.dump(lsvc, os.path.join(out_dir, 'models', label + '.joblib'))
    classifiers += [(label, pruned_indices, lsvc_trans)]

    label = 'DefaultSVC{}Features'.format(len(features))
    svc_trans = 'flatten'
    svc = svm.SVC()
    print(label, svc.get_params())
    svc.fit(getattr(transformations, svc_trans)(X_train[:, pruned_indices]), Y_train)
    joblib.dump(svc, os.path.join(out_dir, 'models', label + '.joblib'))
    classifiers += [(label, pruned_indices, svc_trans)]

    label = 'SVC{}Features'.format(len(features))
    svc_trans = 'flatten'
    svc = svm.SVC(C=1, gamma=0.0001)
    print(label, svc.get_params())
    svc.fit(getattr(transformations, svc_trans)(X_train[:, pruned_indices]), Y_train)
    joblib.dump(svc, os.path.join(out_dir, 'models', label + '.joblib'))
    classifiers += [(label, pruned_indices, svc_trans)]
    
    label = 'RFC{}Features'.format(len(features))
    rfc_trans = 'noop'
    rfc = ensemble.RandomForestClassifier()
    rfc.fit(getattr(transformations, rfc_trans)(X_train[:, pruned_indices]), Y_train)
    joblib.dump(rfc, os.path.join(out_dir, 'models', label + '.joblib'))
    classifiers += [(label, pruned_indices, rfc_trans)]
    
    label = 'GBC{}Features'.format(len(features))
    gbc_trans = 'noop'
    gbc = ensemble.GradientBoostingClassifier()
    gbc.fit(getattr(transformations, rfc_trans)(X_train[:, pruned_indices]), Y_train)
    joblib.dump(gbc, os.path.join(out_dir, 'models', label + '.joblib'))
    classifiers += [(label, pruned_indices, gbc_trans)]
    
print('fit models in {:.1f}s'.format((time.time() - start)))

# %%
X_train.shape, sum(Y_train)

# %%
testing_data = [apps.assemble_data(sample, callers, out_dir) for sample in testing_samples]

# %%
start = time.time()
X_test = np.array(sum([data.result()[0] for data in testing_data], []))
Y_test = np.array(sum([data.result()[1] for data in testing_data], []))

print('assembled testing data in {:.1f}s'.format((time.time() - start)))

# %%
X_test.shape, Y_test.shape

# %%
start = time.time()
futures = []
for sample in testing_samples:
    for label, feature_indices, transformation in classifiers:
        futures += [apps.predict(sample, out_dir, label, feature_indices, transformation, callers)]
polyfuse_data = pd.concat([f.result() for f in futures])
print('assembled predictions in {:.1f}s'.format((time.time() - start)))

# %%
polyfuse_data.to_hdf(os.path.join(out_dir, 'polyfuse_data.hdf'), 'data', mode='w')

# %%
start = time.time()
truth_path = os.path.join(out_dir, 'true_fusions.hdf')
futures = [apps.score(sample, os.path.join(out_dir, 'polyfuse_data.hdf'), truth_path) for sample in testing_samples]
futures += [apps.score(sample, os.path.join(out_dir, 'caller_data.hdf'), truth_path) for sample in testing_samples]
summary = pd.concat([f.result() for f in futures])
print('assembled scores in {:.1f}s'.format((time.time() - start)))

# %%
#ax = sns.boxplot(x="caller", y="average PR", data=summary)
ax = sns.boxplot(x="caller", y="auc", data=summary.sort_values(by='auc', ascending=False))
labels = ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
_ = plt.setp(ax.artists, edgecolor = 'k', facecolor='w')
_ = plt.setp(ax.lines, color='k')
os.makedirs('plots', exist_ok=True)
plt.savefig('plots/auc_RFC_SVC_3-7-8-23_features_sum_J_S.pdf')

# %%
pd.options.display.max_rows = None
summary.groupby('caller').mean().sort_values(by='auc', ascending=False)
# Out:
#                             auc  average PR  total FP  total FN  total TP
# caller
# polyfuseRFC5Features   0.805714  0.939604    32.85     71.25     428.75
# polyfuseRFC4Features   0.799550  0.939043    32.35     74.15     425.85
# polyfuseGBC5Features   0.752892  0.914705    42.85     87.65     412.35
# polyfuseGBC4Features   0.751038  0.909081    46.70     86.20     413.80
# polyfuseLSVC4Features  0.725535  0.901864    47.65     96.30     403.70
# polyfuseLSVC5Features  0.724395  0.909399    42.35     100.10    399.90
# polyfuseSVC4Features   0.721631  0.912547    40.75     103.00    397.00
# polyfuseSVC5Features   0.719811  0.903647    45.25     100.00    400.00
# starfusion             0.714148  0.892422    54.45     98.60     401.40
# starseqr               0.682528  0.839488    130.85    98.95     401.05
# arriba                 0.681154  0.811394    140.50    83.35     416.65
# fusioncatcher          0.635937  0.865766    69.30     130.50    369.50
# pizzly                 0.607858  0.676119    301.65    54.35     445.65

# %%
summary.sort_values(by='auc', ascending=False)
# Out:
#         sample                 caller       auc  average PR  total FP  \
# 0  LIB-04642wt  polyfuseGBC5Features   0.797993  0.940913    39
# 0  LIB-04655wt  polyfuseGBC5Features   0.787991  0.926455    42
# 0  LIB-04657wt  polyfuseGBC4Features   0.785548  0.929155    37
# 0  LIB-04653wt  polyfuseGBC5Features   0.783607  0.920847    33
# 0  LIB-04650wt  polyfuseGBC5Features   0.782698  0.921139    44
# 0  LIB-04655wt  polyfuseGBC4Features   0.782121  0.923471    45
# 0  LIB-04655wt  polyfuseLSVC4Features  0.780568  0.935511    36
# 0  LIB-04642wt  polyfuseGBC4Features   0.780477  0.933984    41
# 0  LIB-04657wt  polyfuseGBC5Features   0.778095  0.922230    42
# 0  LIB-04642wt  polyfuseRFC5Features   0.777375  0.914971    53
# 0  LIB-04655wt  polyfuseLSVC5Features  0.773114  0.936149    34
# 0  LIB-04650wt  polyfuseLSVC4Features  0.772659  0.925540    45
# 0  LIB-04650wt  polyfuseGBC4Features   0.772604  0.915790    47
# 0  LIB-04650wt  polyfuseLSVC5Features  0.770684  0.930846    39
# 0  LIB-04655wt  starfusion             0.770311  0.936413    42
# 0  LIB-04646wt  polyfuseGBC5Features   0.769654  0.914700    47
# 0  LIB-04653wt  polyfuseGBC4Features   0.769023  0.901526    41
# 0  LIB-04655wt  polyfuseSVC4Features   0.768949  0.935026    42
# 0  LIB-04655wt  polyfuseSVC5Features   0.768949  0.935026    42
# 0  LIB-04650wt  polyfuseRFC4Features   0.763193  0.902347    56
# 0  LIB-04642wt  polyfuseRFC4Features   0.762582  0.915205    51
# 0  LIB-04642wt  polyfuseLSVC4Features  0.762169  0.936981    38
# 0  LIB-04655wt  polyfuseRFC5Features   0.760934  0.899071    58
# 0  LIB-04650wt  starfusion             0.760264  0.922919    49
# 0  LIB-04654wt  polyfuseGBC5Features   0.759024  0.903456    61
# 0  LIB-04650wt  polyfuseSVC4Features   0.758724  0.921395    49
# 0  LIB-04650wt  polyfuseSVC5Features   0.758724  0.921395    49
# 0  LIB-04655wt  polyfuseRFC4Features   0.758078  0.899519    59
# 0  LIB-04657wt  polyfuseLSVC4Features  0.757858  0.920787    35
# 0  LIB-04660wt  polyfuseGBC5Features   0.757131  0.906284    45
# 0  LIB-04642wt  polyfuseLSVC5Features  0.756628  0.940259    34
# 0  LIB-04657wt  polyfuseLSVC5Features  0.756249  0.927909    31
# 0  LIB-04646wt  polyfuseGBC4Features   0.755545  0.900377    55
# 0  LIB-04626wt  polyfuseGBC4Features   0.754661  0.911077    51
# 0  LIB-04649wt  polyfuseGBC5Features   0.754521  0.905519    46
# 0  LIB-04657wt  arriba                 0.754293  0.864928    114
# 0  LIB-04657wt  polyfuseSVC5Features   0.753345  0.915380    38
# 0  LIB-04657wt  polyfuseSVC4Features   0.753345  0.915380    38
# 0  LIB-04657wt  starfusion             0.752680  0.914712    38
# 0  LIB-04626wt  polyfuseRFC5Features   0.752053  0.882294    77
# 0  LIB-04653wt  polyfuseRFC5Features   0.752030  0.881298    59
# 0  LIB-04625wt  polyfuseGBC5Features   0.750152  0.914114    44
# 0  LIB-04643wt  polyfuseGBC5Features   0.747166  0.909417    52
# 0  LIB-04654wt  polyfuseGBC4Features   0.747121  0.890568    65
# 0  LIB-04645wt  polyfuseGBC4Features   0.746703  0.909783    41
# 0  LIB-04626wt  polyfuseGBC5Features   0.746615  0.908533    51
# 0  LIB-04650wt  arriba                 0.745931  0.863477    122
# 0  LIB-04647wt  polyfuseGBC5Features   0.744524  0.917869    48
# 0  LIB-04645wt  polyfuseGBC5Features   0.744209  0.909472    40
# 0  LIB-04642wt  starfusion             0.743924  0.911916    54
# 0  LIB-04657wt  polyfuseRFC5Features   0.743877  0.885328    53
# 0  LIB-04653wt  polyfuseLSVC5Features  0.743722  0.920434    33
# 0  LIB-04642wt  polyfuseSVC4Features   0.743627  0.911637    54
# 0  LIB-04642wt  polyfuseSVC5Features   0.743627  0.911637    54
# 0  LIB-04643wt  polyfuseGBC4Features   0.743570  0.910739    48
# 0  LIB-04650wt  polyfuseRFC5Features   0.742942  0.877217    69
# 0  LIB-04651wt  polyfuseGBC5Features   0.741417  0.889482    55
# 0  LIB-04626wt  polyfuseLSVC4Features  0.739785  0.911736    48
# 0  LIB-04660wt  polyfuseGBC4Features   0.739644  0.892047    47
# 0  LIB-04649wt  polyfuseGBC4Features   0.738193  0.899326    49
# 0  LIB-04647wt  polyfuseGBC4Features   0.737641  0.909754    52
# 0  LIB-04626wt  polyfuseRFC4Features   0.737512  0.883457    70
# 0  LIB-04653wt  starfusion             0.737313  0.897647    47
# 0  LIB-04657wt  starseqr               0.736891  0.878733    106
# 0  LIB-04653wt  polyfuseSVC5Features   0.736878  0.897195    47
# 0  LIB-04653wt  polyfuseSVC4Features   0.736878  0.897195    47
# 0  LIB-04654wt  polyfuseRFC5Features   0.736817  0.881768    73
# 0  LIB-04654wt  polyfuseRFC4Features   0.736140  0.883848    69
# 0  LIB-04626wt  polyfuseLSVC5Features  0.734529  0.913636    43
# 0  LIB-04625wt  polyfuseGBC4Features   0.733708  0.899573    50
# 0  LIB-04653wt  polyfuseLSVC4Features  0.733381  0.900749    42
# 0  LIB-04646wt  polyfuseLSVC4Features  0.733205  0.907940    46
# 0  LIB-04649wt  polyfuseRFC5Features   0.731708  0.867673    70
# 0  LIB-04642wt  arriba                 0.731556  0.855049    115
# 0  LIB-04657wt  polyfuseRFC4Features   0.731322  0.880701    57
# 0  LIB-04646wt  polyfuseLSVC5Features  0.730931  0.914673    41
# 0  LIB-04653wt  polyfuseRFC4Features   0.730823  0.865861    61
# 0  LIB-04646wt  polyfuseSVC5Features   0.729755  0.906660    45
# 0  LIB-04646wt  polyfuseSVC4Features   0.729755  0.906660    45
# 0  LIB-04646wt  starfusion             0.729556  0.906460    45
# 0  LIB-04662wt  polyfuseGBC5Features   0.727841  0.906642    49
# 0  LIB-04655wt  arriba                 0.726975  0.854357    134
# 0  LIB-04649wt  polyfuseLSVC4Features  0.726346  0.896920    48
# 0  LIB-04650wt  starseqr               0.726114  0.874035    109
# 0  LIB-04649wt  polyfuseLSVC5Features  0.725375  0.900236    46
# 0  LIB-04674wt  polyfuseGBC5Features   0.725356  0.886646    65
# 0  LIB-04656wt  polyfuseGBC5Features   0.725103  0.898530    38
# 0  LIB-04653wt  arriba                 0.724317  0.837849    127
# 0  LIB-04674wt  polyfuseGBC4Features   0.723844  0.885158    65
# 0  LIB-04626wt  polyfuseSVC4Features   0.723629  0.897348    54
# 0  LIB-04626wt  polyfuseSVC5Features   0.723629  0.897348    54
# 0  LIB-04626wt  starfusion             0.723449  0.897147    54
# 0  LIB-04643wt  polyfuseRFC5Features   0.723387  0.882324    64
# 0  LIB-04654wt  polyfuseLSVC5Features  0.722579  0.917968    43
# 0  LIB-04655wt  starseqr               0.721603  0.875007    112
# 0  LIB-04643wt  polyfuseLSVC5Features  0.721397  0.911497    40
# 0  LIB-04662wt  polyfuseGBC4Features   0.721033  0.895507    57
# 0  LIB-04654wt  polyfuseSVC5Features   0.720611  0.899514    54
# 0  LIB-04654wt  polyfuseSVC4Features   0.720611  0.899514    54
# 0  LIB-04654wt  starfusion             0.720382  0.899284    54
# 0  LIB-04654wt  polyfuseLSVC4Features  0.719839  0.907629    49
# 0  LIB-04643wt  polyfuseLSVC4Features  0.719382  0.903737    46
# 0  LIB-04647wt  polyfuseRFC5Features   0.719189  0.878599    65
# 0  LIB-04656wt  polyfuseGBC4Features   0.718776  0.897455    39
# 0  LIB-04647wt  polyfuseRFC4Features   0.718671  0.888412    60
# 0  LIB-04649wt  starfusion             0.718320  0.897020    51
# 0  LIB-04649wt  polyfuseSVC5Features   0.717628  0.896333    51
# 0  LIB-04649wt  polyfuseSVC4Features   0.717628  0.896333    51
# 0  LIB-04645wt  polyfuseLSVC4Features  0.717342  0.900864    36
# 0  LIB-04649wt  polyfuseRFC4Features   0.717249  0.859270    74
# 0  LIB-04646wt  polyfuseRFC4Features   0.717198  0.867168    70
# 0  LIB-04651wt  polyfuseGBC4Features   0.716059  0.872717    63
# 0  LIB-04652wt  polyfuseLSVC4Features  0.715849  0.906648    51
# 0  LIB-04652wt  polyfuseGBC5Features   0.715128  0.894577    58
# 0  LIB-04647wt  polyfuseLSVC4Features  0.715067  0.895535    55
# 0  LIB-04674wt  polyfuseLSVC5Features  0.714894  0.896375    52
# 0  LIB-04646wt  polyfuseRFC5Features   0.714661  0.861869    74
# 0  LIB-04651wt  polyfuseLSVC5Features  0.714527  0.885385    57
# 0  LIB-04656wt  polyfuseRFC4Features   0.714205  0.870544    58
# 0  LIB-04647wt  polyfuseLSVC5Features  0.714193  0.909312    44
# 0  LIB-04625wt  polyfuseRFC5Features   0.713901  0.857056    75
# 0  LIB-04643wt  polyfuseRFC4Features   0.713385  0.875663    65
# 0  LIB-04625wt  polyfuseRFC4Features   0.713222  0.877088    63
# 0  LIB-04645wt  polyfuseLSVC5Features  0.712869  0.904555    34
# 0  LIB-04652wt  polyfuseLSVC5Features  0.712171  0.912027    46
# 0  LIB-04660wt  polyfuseLSVC5Features  0.711388  0.897989    38
# 0  LIB-04651wt  polyfuseLSVC4Features  0.711132  0.877226    61
# 0  LIB-04656wt  polyfuseRFC5Features   0.711068  0.863026    61
# 0  LIB-04645wt  polyfuseRFC4Features   0.710708  0.870018    55
# 0  LIB-04656wt  polyfuseLSVC4Features  0.709974  0.883348    44
# 0  LIB-04660wt  polyfuseSVC5Features   0.709789  0.891109    48
# 0  LIB-04660wt  polyfuseSVC4Features   0.709789  0.891109    48
# 0  LIB-04660wt  starfusion             0.709749  0.891081    48
# 0  LIB-04652wt  polyfuseGBC4Features   0.709061  0.892114    58
# 0  LIB-04660wt  polyfuseLSVC4Features  0.709060  0.888097    44
# 0  LIB-04674wt  polyfuseLSVC4Features  0.708874  0.884242    60
# 0  LIB-04651wt  starfusion             0.708029  0.877412    62
# 0  LIB-04651wt  polyfuseSVC5Features   0.707431  0.876806    62
# 0  LIB-04651wt  polyfuseSVC4Features   0.707431  0.876806    62
# 0  LIB-04656wt  polyfuseLSVC5Features  0.705493  0.891925    38
# 0  LIB-04642wt  starseqr               0.705271  0.860744    111
# 0  LIB-04644wt  polyfuseGBC5Features   0.704560  0.890997    56
# 0  LIB-04652wt  polyfuseRFC4Features   0.702973  0.867654    72
# 0  LIB-04647wt  arriba                 0.702889  0.835117    127
# 0  LIB-04649wt  arriba                 0.702513  0.833724    120
# 0  LIB-04647wt  starfusion             0.701398  0.884937    62
# 0  LIB-04647wt  polyfuseSVC4Features   0.701185  0.884746    62
# 0  LIB-04647wt  polyfuseSVC5Features   0.701185  0.884746    62
# 0  LIB-04656wt  starfusion             0.701045  0.869284    55
# 0  LIB-04652wt  polyfuseSVC4Features   0.700982  0.886008    63
# 0  LIB-04652wt  polyfuseSVC5Features   0.700982  0.886008    63
# 0  LIB-04656wt  polyfuseSVC4Features   0.700897  0.869113    55
# 0  LIB-04656wt  polyfuseSVC5Features   0.700897  0.869113    55
# 0  LIB-04652wt  starfusion             0.700768  0.885812    63
# 0  LIB-04625wt  polyfuseLSVC5Features  0.698208  0.899367    48
# 0  LIB-04646wt  starseqr               0.697732  0.857154    115
# 0  LIB-04643wt  polyfuseSVC5Features   0.697365  0.881785    57
# 0  LIB-04643wt  polyfuseSVC4Features   0.697365  0.881785    57
# 0  LIB-04643wt  starfusion             0.696755  0.881163    57
# 0  LIB-04625wt  polyfuseLSVC4Features  0.696628  0.885899    56
# 0  LIB-04660wt  polyfuseRFC5Features   0.696336  0.837807    76
# 0  LIB-04642wt  pizzly                 0.695808  0.780118    188
# 0  LIB-04645wt  polyfuseSVC4Features   0.695711  0.880392    49
# 0  LIB-04645wt  polyfuseSVC5Features   0.695711  0.880392    49
# 0  LIB-04645wt  starfusion             0.695706  0.880425    49
# 0  LIB-04651wt  polyfuseRFC4Features   0.695676  0.840974    80
# 0  LIB-04644wt  polyfuseLSVC4Features  0.695586  0.877550    59
# 0  LIB-04646wt  arriba                 0.692656  0.826797    127
# 0  LIB-04674wt  starfusion             0.691946  0.877759    61
# 0  LIB-04674wt  arriba                 0.691834  0.833028    144
# 0  LIB-04674wt  polyfuseRFC5Features   0.691002  0.857641    83
# 0  LIB-04674wt  polyfuseSVC5Features   0.690904  0.876703    61
# 0  LIB-04674wt  polyfuseSVC4Features   0.690904  0.876703    61
# 0  LIB-04644wt  polyfuseLSVC5Features  0.689264  0.885818    53
# 0  LIB-04645wt  polyfuseRFC5Features   0.688846  0.855140    62
# 0  LIB-04651wt  polyfuseRFC5Features   0.688668  0.830307    88
# 0  LIB-04653wt  starseqr               0.688499  0.827871    139
# 0  LIB-04662wt  polyfuseRFC5Features   0.688164  0.847928    90
# 0  LIB-04647wt  starseqr               0.687020  0.830153    149
# 0  LIB-04662wt  polyfuseLSVC4Features  0.686001  0.890347    54
# 0  LIB-04644wt  polyfuseGBC4Features   0.684851  0.872274    64
# 0  LIB-04674wt  starseqr               0.684095  0.844932    140
# 0  LIB-04625wt  starfusion             0.683447  0.881310    62
# 0  LIB-04649wt  starseqr               0.683374  0.837380    126
# 0  LIB-04643wt  arriba                 0.683272  0.807824    152
# 0  LIB-04626wt  starseqr               0.682706  0.825122    136
# 0  LIB-04625wt  starseqr               0.682303  0.849996    115
# 0  LIB-04625wt  polyfuseSVC5Features   0.682081  0.880010    62
# 0  LIB-04625wt  polyfuseSVC4Features   0.682081  0.880010    62
# 0  LIB-04674wt  polyfuseRFC4Features   0.681733  0.848160    84
# 0  LIB-04654wt  starseqr               0.679806  0.844852    124
# 0  LIB-04662wt  polyfuseLSVC5Features  0.679692  0.891631    53
# 0  LIB-04644wt  polyfuseRFC5Features   0.679256  0.856658    79
# 0  LIB-04644wt  polyfuseRFC4Features   0.678711  0.859403    74
# 0  LIB-04644wt  polyfuseSVC5Features   0.678430  0.868097    68
# 0  LIB-04644wt  polyfuseSVC4Features   0.678430  0.868097    68
# 0  LIB-04652wt  polyfuseRFC5Features   0.678044  0.840880    85
# 0  LIB-04644wt  starfusion             0.677855  0.867518    68
# 0  LIB-04626wt  arriba                 0.675348  0.802435    131
# 0  LIB-04643wt  starseqr               0.673927  0.835135    116
# 0  LIB-04650wt  fusioncatcher          0.673774  0.877774    61
# 0  LIB-04645wt  arriba                 0.673690  0.809679    128
# 0  LIB-04662wt  polyfuseRFC4Features   0.672942  0.842015    99
# 0  LIB-04654wt  arriba                 0.669877  0.802199    143
# 0  LIB-04660wt  starseqr               0.669580  0.842905    113
# 0  LIB-04625wt  fusioncatcher          0.665857  0.896695    53
# 0  LIB-04652wt  starseqr               0.664101  0.831827    149
# 0  LIB-04645wt  starseqr               0.663314  0.830014    142
# 0  LIB-04655wt  fusioncatcher          0.663310  0.876379    56
# 0  LIB-04643wt  pizzly                 0.662338  0.735268    263
# 0  LIB-04660wt  polyfuseRFC4Features   0.662026  0.788917    88
# 0  LIB-04656wt  starseqr               0.661586  0.806950    147
# 0  LIB-04662wt  starfusion             0.660055  0.868225    68
# 0  LIB-04653wt  fusioncatcher          0.659857  0.882908    66
# 0  LIB-04642wt  fusioncatcher          0.659699  0.893762    60
# 0  LIB-04662wt  polyfuseSVC5Features   0.658946  0.867091    68
# 0  LIB-04662wt  polyfuseSVC4Features   0.658946  0.867091    68
# 0  LIB-04656wt  arriba                 0.656519  0.796015    126
# 0  LIB-04625wt  pizzly                 0.655283  0.715517    249
# 0  LIB-04651wt  starseqr               0.653914  0.807720    151
# 0  LIB-04626wt  pizzly                 0.652810  0.728725    229
# 0  LIB-04660wt  arriba                 0.651888  0.782926    146
# 0  LIB-04674wt  fusioncatcher          0.650984  0.864776    76
# 0  LIB-04650wt  pizzly                 0.649543  0.707032    408
# 0  LIB-04662wt  starseqr               0.649015  0.823425    137
# 0  LIB-04625wt  arriba                 0.648644  0.787885    136
# 0  LIB-04652wt  arriba                 0.646821  0.785075    158
# 0  LIB-04662wt  arriba                 0.644119  0.778872    183
# 0  LIB-04649wt  fusioncatcher          0.642303  0.848291    84
# 0  LIB-04662wt  fusioncatcher          0.640775  0.876534    73
# 0  LIB-04660wt  fusioncatcher          0.639748  0.861117    70
# 0  LIB-04644wt  starseqr               0.639718  0.805809    180
# 0  LIB-04662wt  pizzly                 0.638505  0.717633    286
# 0  LIB-04655wt  pizzly                 0.636251  0.697657    268
# 0  LIB-04657wt  fusioncatcher          0.635270  0.884576    66
# 0  LIB-04645wt  fusioncatcher          0.633125  0.877733    55
# 0  LIB-04626wt  fusioncatcher          0.632263  0.862135    75
# 0  LIB-04647wt  fusioncatcher          0.631735  0.870157    59
# 0  LIB-04644wt  fusioncatcher          0.628526  0.857135    72
# 0  LIB-04657wt  pizzly                 0.623724  0.686373    248
# 0  LIB-04654wt  pizzly                 0.620646  0.695716    282
# 0  LIB-04653wt  pizzly                 0.619286  0.681949    282
# 0  LIB-04654wt  fusioncatcher          0.619153  0.865962    68
# 0  LIB-04652wt  fusioncatcher          0.618370  0.851931    79
# 0  LIB-04646wt  fusioncatcher          0.611118  0.849268    73
# 0  LIB-04651wt  arriba                 0.608924  0.735724    181
# 0  LIB-04656wt  fusioncatcher          0.606054  0.847267    69
# 0  LIB-04643wt  fusioncatcher          0.605026  0.854536    78
# 0  LIB-04651wt  fusioncatcher          0.601790  0.816380    93
# 0  LIB-04649wt  pizzly                 0.599792  0.674067    287
# 0  LIB-04647wt  pizzly                 0.596136  0.650270    348
# 0  LIB-04644wt  arriba                 0.591011  0.734917    196
# 0  LIB-04674wt  pizzly                 0.588085  0.663125    300
# 0  LIB-04656wt  pizzly                 0.583849  0.659062    275
# 0  LIB-04646wt  pizzly                 0.575390  0.631248    380
# 0  LIB-04645wt  pizzly                 0.573021  0.647442    311
# 0  LIB-04660wt  pizzly                 0.562982  0.631936    288
# 0  LIB-04644wt  pizzly                 0.561916  0.623430    417
# 0  LIB-04652wt  pizzly                 0.546309  0.614596    396
# 0  LIB-04651wt  pizzly                 0.515489  0.581225    328
#
#    total FN  total TP
# 0  77        423
# 0  75        425
# 0  77        423
# 0  73        427
# 0  75        425
# 0  77        423
# 0  83        417
# 0  83        417
# 0  78        422
# 0  76        424
# 0  87        413
# 0  83        417
# 0  78        422
# 0  86        414
# 0  90        410
# 0  79        421
# 0  71        429
# 0  90        410
# 0  90        410
# 0  77        423
# 0  84        416
# 0  94        406
# 0  77        423
# 0  89        411
# 0  81        419
# 0  89        411
# 0  89        411
# 0  79        421
# 0  87        413
# 0  81        419
# 0  98        402
# 0  91        409
# 0  80        420
# 0  86        414
# 0  82        418
# 0  68        432
# 0  87        413
# 0  87        413
# 0  87        413
# 0  75        425
# 0  72        428
# 0  89        411
# 0  89        411
# 0  81        419
# 0  88        412
# 0  89        411
# 0  73        427
# 0  95        405
# 0  89        411
# 0  93        407
# 0  78        422
# 0  94        406
# 0  93        407
# 0  93        407
# 0  91        409
# 0  76        424
# 0  82        418
# 0  94        406
# 0  83        417
# 0  88        412
# 0  95        405
# 0  83        417
# 0  87        413
# 0  86        414
# 0  87        413
# 0  87        413
# 0  83        417
# 0  84        416
# 0  97        403
# 0  91        409
# 0  90        410
# 0  95        405
# 0  77        423
# 0  76        424
# 0  83        417
# 0  99        401
# 0  75        425
# 0  96        404
# 0  96        404
# 0  96        404
# 0  98        402
# 0  81        419
# 0  93        407
# 0  90        410
# 0  95        405
# 0  91        409
# 0  93        407
# 0  71        429
# 0  91        409
# 0  96        404
# 0  96        404
# 0  96        404
# 0  89        411
# 0  106       394
# 0  94        406
# 0  102       398
# 0  97        403
# 0  99        401
# 0  99        401
# 0  99        401
# 0  103       397
# 0  100       400
# 0  90        410
# 0  96        404
# 0  95        405
# 0  98        402
# 0  98        402
# 0  98        402
# 0  98        402
# 0  81        419
# 0  85        415
# 0  88        412
# 0  105       395
# 0  100       400
# 0  100       400
# 0  100       400
# 0  84        416
# 0  95        405
# 0  87        413
# 0  106       394
# 0  82        418
# 0  91        409
# 0  92        408
# 0  102       398
# 0  109       391
# 0  100       400
# 0  93        407
# 0  85        415
# 0  88        412
# 0  94        406
# 0  99        401
# 0  99        401
# 0  99        401
# 0  102       398
# 0  97        403
# 0  98        402
# 0  95        405
# 0  95        405
# 0  95        405
# 0  100       400
# 0  95        405
# 0  103       397
# 0  94        406
# 0  83        417
# 0  81        419
# 0  103       397
# 0  103       397
# 0  103       397
# 0  93        407
# 0  104       396
# 0  104       396
# 0  93        407
# 0  93        407
# 0  104       396
# 0  110       390
# 0  98        402
# 0  102       398
# 0  102       398
# 0  102       398
# 0  105       395
# 0  81        419
# 0  58        442
# 0  101       399
# 0  101       399
# 0  101       399
# 0  84        416
# 0  101       399
# 0  84        416
# 0  104       396
# 0  91        409
# 0  97        403
# 0  104       396
# 0  104       396
# 0  108       392
# 0  93        407
# 0  83        417
# 0  89        411
# 0  94        406
# 0  93        407
# 0  113       387
# 0  105       395
# 0  103       397
# 0  111       389
# 0  96        404
# 0  81        419
# 0  90        410
# 0  103       397
# 0  111       389
# 0  111       389
# 0  97        403
# 0  103       397
# 0  117       383
# 0  102       398
# 0  103       397
# 0  107       393
# 0  107       393
# 0  95        405
# 0  107       393
# 0  80        420
# 0  99        401
# 0  114       386
# 0  85        415
# 0  101       399
# 0  85        415
# 0  106       394
# 0  127       373
# 0  109       391
# 0  107       393
# 0  118       382
# 0  56        444
# 0  74        426
# 0  94        406
# 0  118       382
# 0  126       374
# 0  131       369
# 0  118       382
# 0  118       382
# 0  87        413
# 0  45        455
# 0  100       400
# 0  55        445
# 0  84        416
# 0  123       377
# 0  53        447
# 0  111       389
# 0  88        412
# 0  91        409
# 0  92        408
# 0  120       380
# 0  135       365
# 0  126       374
# 0  113       387
# 0  62        438
# 0  47        453
# 0  141       359
# 0  135       365
# 0  132       368
# 0  133       367
# 0  130       370
# 0  47        453
# 0  59        441
# 0  49        451
# 0  140       360
# 0  135       365
# 0  136       364
# 0  86        414
# 0  137       363
# 0  144       356
# 0  127       373
# 0  58        442
# 0  46        454
# 0  100       400
# 0  60        440
# 0  58        442
# 0  49        451
# 0  60        440
# 0  54        446
# 0  56        444
# 0  61        439
# 0  54        446
